# %% [markdown]
# # COURSERA CAPSTONE PROJECT

# %% [markdown]
# This notebook will be used for the coursera "applied data science Capostone" course

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20201107091240-0000
# KERNEL_ID = 19f9c3a7-279a-494c-9fd6-c86ae3712497
# Hello Capstone Project Course!
